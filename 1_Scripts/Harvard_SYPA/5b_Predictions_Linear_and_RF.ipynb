# %% [markdown]
# **SYPA: Fundamental Analysis of Foreign Direct Investment** <br>
# *5b_Predictions_Linear_and_RF* <br>
# Harvard SYPA <br>
# User: Jake Schneider <br>
# Date Created: March 4, 2020 <br>
# Date Updated: March 5, 2020

# %% [markdown]
# ----

# %% [markdown]
# **Note: This needs to be run from the tfcs109a Conda Environment**

# %% [markdown]
# **Load Packages**

# %%
#Import libraries
import sys
import pandas as pd
from datetime import date, datetime, time, timedelta
import pendulum
import json
import requests
import numpy as np
import math

from scitime import Estimator 

import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style='ticks', context='talk')

from matplotlib.offsetbox import AnchoredText
from sklearn import metrics
from sklearn import linear_model
from sklearn.linear_model import LinearRegression 
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.linear_model import Lasso, LassoCV
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor 
from sklearn.tree import export_graphviz
import pydot

import pickle

import statsmodels.formula.api as sm
from pprint import pprint

import warnings
import itertools

import missingno as msno

from flask import jsonify, make_response

from varname import varname

from matplotlib.backends.backend_pdf import PdfPages
from fpdf import FPDF
from PIL import Image, ImageDraw, ImageFont

# %% [markdown]
# ----

# %% [markdown]
# **Load Data**

# %%
# Load Data

final_df = pd.read_csv('../../2_Inputs/Final/final_df.csv')
final_df = final_df.drop(["Unnamed: 0"], axis = 1)
final_df.head()
# Out:
#        country    date code iso2Code      region adminregion incomeLevel  \
# 0  Afghanistan  1960.0  AFG       AF  South Asia  South Asia  Low income
# 1  Afghanistan  1961.0  AFG       AF  South Asia  South Asia  Low income
# 2  Afghanistan  1962.0  AFG       AF  South Asia  South Asia  Low income
# 3  Afghanistan  1963.0  AFG       AF  South Asia  South Asia  Low income
# 4  Afghanistan  1964.0  AFG       AF  South Asia  South Asia  Low income
#
#   lendingType capitalCity  longitude  ...  \
# 0         IDA       Kabul    69.1761  ...
# 1         IDA       Kabul    69.1761  ...
# 2         IDA       Kabul    69.1761  ...
# 3         IDA       Kabul    69.1761  ...
# 4         IDA       Kabul    69.1761  ...
#
#    Ratio.of.female.to.male.labor.force.participation.rate......modeled.ILO.estimate.  \
# 0                                          74.856875
# 1                                          74.856875
# 2                                          71.941730
# 3                                          54.693568
# 4                                          59.874157
#
#    Unemployment..total....of.total.labor.force...modeled.ILO.estimate.  \
# 0                                             4.1602
# 1                                             7.6538
# 2                                             5.2414
# 3                                             7.0762
# 4                                             6.8932
#
#    Net.migration  Prevalence.of.undernourishment....of.population.  \
# 0       276087.2                                              13.9
# 1       195999.6                                              13.9
# 2       -20000.0                                              13.9
# 3       278921.8                                              13.9
# 4       195999.6                                              13.9
#
#    Life.expectancy.at.birth..total..years.  \
# 0                                   32.446
# 1                                   32.962
# 2                                   33.471
# 3                                   33.971
# 4                                   34.463
#
#    Fertility.rate..total..births.per.woman.  \
# 0                                      7.45
# 1                                      7.45
# 2                                      7.45
# 3                                      7.45
# 4                                      7.45
#
#    Population.ages.65.and.above....of.total.population.  \
# 0                                           2.798308
# 1                                           2.808131
# 2                                           2.804113
# 3                                           2.786171
# 4                                           2.754223
#
#    Unmet.need.for.contraception....of.married.women.ages.15.49.  \
# 0                                              15.06
# 1                                              15.06
# 2                                              15.06
# 3                                              15.06
# 4                                              15.06
#
#    Voice.and.Accountability..Estimate.y    year
# 0                             -0.199767  1960.0
# 1                             -0.199767  1961.0
# 2                             -0.199767  1962.0
# 3                             -0.193007  1963.0
# 4                             -0.193007  1964.0
#
# [5 rows x 2324 columns]

# %%
# Load In Sample

in_sample = pd.read_csv('../../2_Inputs/Final/in_sample.csv')
in_sample = in_sample.drop(["Unnamed: 0"], axis = 1)
in_sample.head()
# Out:
#        country    date code iso2Code      region adminregion incomeLevel  \
# 0  Afghanistan  1970.0  AFG       AF  South Asia  South Asia  Low income
# 1  Afghanistan  1971.0  AFG       AF  South Asia  South Asia  Low income
# 2  Afghanistan  1972.0  AFG       AF  South Asia  South Asia  Low income
# 3  Afghanistan  1973.0  AFG       AF  South Asia  South Asia  Low income
# 4  Afghanistan  1976.0  AFG       AF  South Asia  South Asia  Low income
#
#   lendingType capitalCity  longitude  ...  \
# 0         IDA       Kabul    69.1761  ...
# 1         IDA       Kabul    69.1761  ...
# 2         IDA       Kabul    69.1761  ...
# 3         IDA       Kabul    69.1761  ...
# 4         IDA       Kabul    69.1761  ...
#
#    Ratio.of.female.to.male.labor.force.participation.rate......modeled.ILO.estimate.  \
# 0                                          78.003300
# 1                                          78.201934
# 2                                          72.199611
# 3                                          69.824106
# 4                                          77.278710
#
#    Unemployment..total....of.total.labor.force...modeled.ILO.estimate.  \
# 0                                             8.3546
# 1                                             8.5824
# 2                                             8.7142
# 3                                             6.7992
# 4                                             4.2436
#
#    Net.migration  Prevalence.of.undernourishment....of.population.  \
# 0       -23616.0                                             43.52
# 1       -22903.2                                             43.88
# 2       -20000.0                                             26.32
# 3       -14881.2                                             35.16
# 4      -261777.8                                             38.10
#
#    Life.expectancy.at.birth..total..years.  \
# 0                                   37.409
# 1                                   37.930
# 2                                   38.461
# 3                                   39.003
# 4                                   40.715
#
#    Fertility.rate..total..births.per.woman.  \
# 0                                      7.45
# 1                                      7.45
# 2                                      7.45
# 3                                      7.45
# 4                                      7.45
#
#    Population.ages.65.and.above....of.total.population.  \
# 0                                           2.631613
# 1                                           2.635235
# 2                                           2.627456
# 3                                           2.609505
# 4                                           2.558353
#
#    Unmet.need.for.contraception....of.married.women.ages.15.49.  \
# 0                                              29.48
# 1                                              29.68
# 2                                              26.70
# 3                                              27.00
# 4                                              28.06
#
#    Voice.and.Accountability..Estimate.y    year
# 0                             -0.979531  1970.0
# 1                             -0.956633  1971.0
# 2                             -1.043920  1972.0
# 3                             -0.792020  1973.0
# 4                             -0.555133  1976.0
#
# [5 rows x 2316 columns]

# %%
# Load Lock Box

lock_box = pd.read_csv('../../2_Inputs/Final/lock_box.csv')
lock_box = lock_box.drop(["Unnamed: 0"], axis = 1)
print(lock_box.shape)
lock_box.head()
# Out:
# (757, 2316)
#        country    date code iso2Code                 region  \
# 0  Afghanistan  2015.0  AFG       AF             South Asia
# 1  Afghanistan  2016.0  AFG       AF             South Asia
# 2  Afghanistan  2017.0  AFG       AF             South Asia
# 3  Afghanistan  2018.0  AFG       AF             South Asia
# 4      Albania  2015.0  ALB       AL  Europe & Central Asia
#
#                                      adminregion          incomeLevel  \
# 0                                     South Asia           Low income
# 1                                     South Asia           Low income
# 2                                     South Asia           Low income
# 3                                     South Asia           Low income
# 4  Europe & Central Asia (excluding high income)  Upper middle income
#
#   lendingType capitalCity  longitude  ...  \
# 0         IDA       Kabul    69.1761  ...
# 1         IDA       Kabul    69.1761  ...
# 2         IDA       Kabul    69.1761  ...
# 3         IDA       Kabul    69.1761  ...
# 4        IBRD      Tirane    19.8172  ...
#
#    Ratio.of.female.to.male.labor.force.participation.rate......modeled.ILO.estimate.  \
# 0                                          57.110746
# 1                                          58.104539
# 2                                          59.008129
# 3                                          59.244647
# 4                                          73.166459
#
#    Unemployment..total....of.total.labor.force...modeled.ILO.estimate.  \
# 0                                              1.679
# 1                                              1.634
# 2                                              1.559
# 3                                              1.542
# 4                                             17.080
#
#    Net.migration  Prevalence.of.undernourishment....of.population.  \
# 0       -16498.2                                             28.60
# 1       -16498.2                                             29.50
# 2      -314602.0                                             29.80
# 3       -32328.2                                             27.96
# 4      -131596.4                                              6.00
#
#    Life.expectancy.at.birth..total..years.  \
# 0                                  63.3770
# 1                                  63.7630
# 2                                  64.1300
# 3                                  63.3522
# 4                                  78.0250
#
#    Fertility.rate..total..births.per.woman.  \
# 0                                    4.9760
# 1                                    4.8000
# 2                                    4.6330
# 3                                    4.9862
# 4                                    1.6770
#
#    Population.ages.65.and.above....of.total.population.  \
# 0                                           2.478662
# 1                                           2.519923
# 2                                           2.554251
# 3                                           2.584927
# 4                                          12.626548
#
#    Unmet.need.for.contraception....of.married.women.ages.15.49.  \
# 0                                              24.50
# 1                                              25.64
# 2                                              22.98
# 3                                              25.86
# 4                                              17.16
#
#    Voice.and.Accountability..Estimate.y    year
# 0                             -1.117563  2015.0
# 1                             -1.039843  2016.0
# 2                             -0.992470  2017.0
# 3                             -0.994720  2018.0
# 4                              0.157149  2015.0
#
# [5 rows x 2316 columns]

# %%
# Lock Box Shape

lock_box.shape
# Out:
# (757, 2316)

# %%
# Split Lock Box

#lock_box = lock_box.loc[:,'longitude':]
lock_box_x = lock_box.drop(lock_box[['country', 'date', 'code', 'iso2Code', 'region', 'adminregion','incomeLevel', 'lendingType', 'capitalCity','Foreign direct investment, net inflows (% of GDP)']], axis = 1)
lock_box_y = lock_box['Foreign direct investment, net inflows (% of GDP)']

print(lock_box_x.shape)
print(lock_box_y.shape)
# Out:
# (757, 2306)
# (757,)

# %%
# Load Validation Table

results = pd.read_csv('../../3_Outputs/Model Selection/Validation Table/Validation Table 3.csv')
results = results.drop(["Unnamed: 0"], axis = 1)
results.head()
# Out:
#                    Model Name       Model Type  Minimum RMSE  Variables
# 0           Linear Regression     Linear Model      20021.89       2313
# 1            Ridge Regression     Linear Model      12131.99       2310
# 2            Lasso Regression     Linear Model        462.40        986
# 3               Random Forest       Tree-Based        143.22       2310
# 4  Deep Neural Networks (DNN)  Neural Networks         91.71       2310

# %% [markdown]
# ---

# %% [markdown]
# **Import Second Best non-NN Models: Lasso and Random Forest** <br>

# %% [markdown]
# *Lasso*

# %%
# load the model from disk
lasso_optimum = pickle.load(open('../../3_Outputs/Model Selection/Lasso Regression/lasso_optimum_model.sav', 'rb'))
print("Load rf optimum from disk")
# Out:
# Load rf optimum from disk

# %% [markdown]
# *Random Forest*

# %%
# load the model from disk
rf_optimum = pickle.load(open('../../3_Outputs/Model Selection/Random Forest/rf_optimum_model.sav', 'rb'))
print("Load rf optimum from disk")
# Out:
# Load rf optimum from disk

# %% [markdown]
# ----

# %% [markdown]
# **Predict Values Using Lasso**

# %% [markdown]
# *Predict Lasso*

# %%
# Create Predictions

prediction_lasso = lasso_optimum.predict(lock_box_x)

# %%
# View Predictions

y_pred_lasso = prediction_lasso
print(len(y_pred_lasso))
print('Prediction with scaling - {}'.format(y_pred_lasso[0:10]))
# Out:
# 757
# Prediction with scaling - [ 19.33158518  13.73869089  26.25710913  38.68882972 -11.28288851
#   -6.94807892  -3.56554522   0.23250231  -5.59801667  -9.22454087]

# %%
y_pred_lasso_df = pd.DataFrame(data = y_pred_lasso)
y_pred_lasso_df.head(25)
# Out:
#              0
# 0    19.331585
# 1    13.738691
# 2    26.257109
# 3    38.688830
# 4   -11.282889
# 5    -6.948079
# 6    -3.565545
# 7     0.232502
# 8    -5.598017
# 9    -9.224541
# 10   -4.527827
# 11    3.369876
# 12   12.040654
# 13   -0.866079
# 14    7.158693
# 15   12.756854
# 16   12.466021
# 17   11.195864
# 18   13.892777
# 19   15.015834
# 20   56.280659
# 21  110.962708
# 22  262.895139
# 23  223.624115
# 24   -4.338054

# %% [markdown]
# ----

# %% [markdown]
# **Predict Values Using Random Forest**

# %% [markdown]
# *Predict Random Forest*

# %%
# Create Predictions

prediction_rf = rf_optimum.predict(lock_box_x)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 800 out of 800 | elapsed:    0.1s finished

# %%
# View Predictions

y_pred_rf = prediction_rf
print(len(y_pred_rf))
print('Prediction with scaling - {}'.format(y_pred_rf[0:10]))
# Out:
# 757
# Prediction with scaling - [3.02757827 3.26208424 3.38053037 3.16497445 5.59971484 5.66581733
#  5.76952183 5.06197014 3.1209371  3.26449848]

# %%
y_pred_rf_df = pd.DataFrame(data = y_pred_rf)
y_pred_rf_df.head(25)
# Out:
#             0
# 0    3.027578
# 1    3.262084
# 2    3.380530
# 3    3.164974
# 4    5.599715
# 5    5.665817
# 6    5.769522
# 7    5.061970
# 8    3.120937
# 9    3.264498
# 10   3.128568
# 11   2.902362
# 12   3.186174
# 13   3.405694
# 14   3.364097
# 15   4.155141
# 16   9.797954
# 17   9.769076
# 18  11.095391
# 19  11.435078
# 20   3.031589
# 21   3.521913
# 22   3.424847
# 23   3.663189
# 24   4.511215

# %%
lock_box_y.head(25)
# Out:
# 0     0.849679
# 1     0.483360
# 2     0.255222
# 3     0.718898
# 4     8.690477
# 5     8.804978
# 6     7.852228
# 7     7.992357
# 8    -0.324014
# 9     1.023704
# 10    0.717464
# 11    0.866905
# 12    8.630605
# 13   -0.177523
# 14   -6.057209
# 15   -5.420745
# 16    8.039283
# 17    5.613403
# 18    7.693360
# 19    7.233055
# 20    1.977135
# 21    0.584750
# 22    1.791961
# 23    2.283806
# 24    1.744737
# Name: Foreign direct investment, net inflows (% of GDP), dtype: float64
