# %% [markdown]
# **SYPA: Fundamental Analysis of Foreign Direct Investment** <br>
# *1_API* <br>
# Harvard SYPA <br>
# User: Jake Schneider <br>
# Date Created: February 7, 2020 <br>
# Date Updated: February 8, 2020

# %% [markdown]
# ----

# %% [markdown]
# **Load Packages**

# %%
#Import libraries
import sys
import pandas as pd
from datetime import date, datetime, time, timedelta
import pendulum
import json
import requests
import numpy as np
import math

import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style='ticks', context='talk')

from matplotlib.offsetbox import AnchoredText
from sklearn import linear_model
from sklearn.metrics import r2_score
import statsmodels.api as sm
#import fbprophet

import warnings
import itertools

from flask import jsonify, make_response

from varname import varname

from matplotlib.backends.backend_pdf import PdfPages
from fpdf import FPDF
from PIL import Image, ImageDraw, ImageFont

# %%
# Create function 'jprint'

def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

# %% [markdown]
# ----

# %% [markdown]
# **Pull Economic Data from APIs: World Bank, Systemic Peace Project (Polity IV), World Wide Governance Indicators** <br>
# *Bloomberg API for Python?*

# %%
# Configure World Bank

import config_world_bank

#print(config_world_bank)

#api_key_wb = config_world_bank.api_key #API key no longer required
user_agent = 'Jake_Schneider'

# %%
##Test
#
#test = requests.get('http://api.worldbank.org/v2/country/all/indicator/SP.POP.TOTL?date=2000:2001&format=json')
#jprint(test.json())

# %%
# Create Function For Pulling Economic Data from World Bank

def parse_wb(country, series, start_date = '1970', end_date = '2020'):
    values = requests.get('http://api.worldbank.org/v2/country/{}/indicator/{}?date={}:{}&format=json'.format(country, series, start_date, end_date))
    length = len(values.json())
    #print(length)
    jprint(values.json()) #["observations"][length-1])
    return values.json() #["observations"][length-1]

# %%
## Run Function 'Parse_wb'
## 'SP.POP.TOTL' = Total Population
#
#wb_indicators = ['SP.POP.TOTL']
#
#wb_master_data = []
#for indicator in wb_indicators:
#    wb_data = parse_wb(country = 'all', series = indicator)
#    wb_master_data.append(wb_data)

# %% [markdown]
# ---

# %% [markdown]
# **Import Data through Pandas Data Reader** <br>
# Docs: https://pandas-datareader.readthedocs.io/en/latest/remote_data.html#world-bank

# %% [markdown]
# *Import PDR*

# %%
## Import pandas_datareader
#
#from pandas_datareader import data, wb
#import pandas_datareader as pdr

# %% [markdown]
# *Test PDR*

# %%
## TEST: Use PDR for FRED
#
#pdr.get_data_fred('GS10')

# %% [markdown]
# *Find Indicators: Macro and Governance*

# %%
## Find Indicators for FDI Project: GDP
#
#matches_gdp = wb.search('gdp.*.*')
#print(len(matches_gdp))
#matches_gdp.head()

# %%
## Store Indicators As a Variable: GDP
#
#list_gdp = list(matches_gdp['id'])
#print("The number of GDP variables are: ", len(list_gdp))
##print(list_gdp)

# %% [markdown]
# *Download Indicators*

# %%
#for num, indicator in zip(range(1, len(list_gdp)+1), list_gdp):
#    if num % 10 == 0:
#        print(num, "/", len(list_gdp), ":", indicator)

#data_wb = wb.download(indicator='5.51.01.10.gdp', country='all', start=1960, end=2018)

# %%
#data_wb

# %% [markdown]
# ----

# %% [markdown]
# **Import Data through wbdata** <br>
# Docs: https://wbdata.readthedocs.io/en/stable/ <br>
# Example: https://mcmayer.net/getting-worldbank-data-with-python-easily/

# %% [markdown]
# *Import wbdata*

# %%
# Import wbdata

import wbdata

# %% [markdown]
# *Download and Explore*

# %%
# Download wbdata sources

sources = wbdata.get_source(display = False)
#sources

# %% [markdown]
# *Find Indicators*

# %%
## Search for Indicators: GDP
#
#wbdata.search_indicators("gdp per capita")

# %% [markdown]
# *Cull Datasets: WDI (2), Doing Business (1), WGI (3), International Debt Statistics (6), CPIA (31), Worldwide Bureaucracy Indicators (64), ESG (75)*

# %%
# Download World Development Indicators (2)

wdi = wbdata.get_indicator(source=2, display = False)
#wdi

# %%
#Create list of WDI IDs

wdi_ids = []
wdi_names = []

for num in range(0, len(wdi)):
    wdi_ids.append(wdi[num]["id"])
    wdi_names.append(wdi[num]["name"])
    
print(len(wdi_ids))
print(wdi_ids[0:5])
print(wdi_names[0:5])
# Out:
# 1429
# ['AG.AGR.TRAC.NO', 'AG.CON.FERT.PT.ZS', 'AG.CON.FERT.ZS', 'AG.LND.AGRI.K2', 'AG.LND.AGRI.ZS']
# ['Agricultural machinery, tractors', 'Fertilizer consumption (% of fertilizer production)', 'Fertilizer consumption (kilograms per hectare of arable land)', 'Agricultural land (sq. km)', 'Agricultural land (% of land area)']

# %%
# Download Doing Business (1)

doing_business = wbdata.get_indicator(source=1, display = False)
#doing_business

# %%
#Create list of Doing Business IDs

doing_business_ids = []
doing_business_names = []

for num in range(0, len(doing_business)):
    doing_business_ids.append(doing_business[num]["id"])
    doing_business_names.append(doing_business[num]["name"])
    
print(len(doing_business_ids))
print(doing_business_ids[0:5])
print(doing_business_names[0:5])
# Out:
# 205
# ['ENF.CONT.COEN.ATDR', 'ENF.CONT.COEN.ATFE.PR', 'ENF.CONT.COEN.COST.ZS', 'ENF.CONT.COEN.COST.ZS.DFRN', 'ENF.CONT.COEN.CSMG']
# ['Enforcing contracts: Alternative dispute resolution (0-3) (DB16-20 methodology)', 'Enforcing contracts: Attorney fees (% of claim)', 'Enforcing contracts: Cost (% of claim)', 'Enforcing contracts: Cost (% of claim) - Score', 'Enforcing contracts: Case management (0-6) (DB16-20 methodology)']

# %%
# Download WGI (3)

wgi = wbdata.get_indicator(source=3, display = False)
#wgi

# %%
#Create list of WGI IDs

wgi_ids = []
wgi_names = []

for num in range(0, len(wgi)):
    wgi_ids.append(wgi[num]["id"])
    wgi_names.append(wgi[num]["name"])
    
print(len(wgi_ids))
print(wgi_ids[0:5])
print(wgi_names[0:5])
# Out:
# 36
# ['CC.EST', 'CC.NO.SRC', 'CC.PER.RNK', 'CC.PER.RNK.LOWER', 'CC.PER.RNK.UPPER']
# ['Control of Corruption: Estimate', 'Control of Corruption: Number of Sources', 'Control of Corruption: Percentile Rank', 'Control of Corruption: Percentile Rank, Lower Bound of 90% Confidence Interval', 'Control of Corruption: Percentile Rank, Upper Bound of 90% Confidence Interval']

# %%
# Download International Debt Stats (6)

debt = wbdata.get_indicator(source=6, display = False)
#debt

# %%
#Create list of International Debt Statistics IDs

debt_ids = []
debt_names = []

for num in range(0, len(debt)):
    debt_ids.append(debt[num]["id"])
    debt_names.append(debt[num]["name"])
    
print(len(debt_ids))
print(debt_ids[0:5])
print(debt_names[0:5])
# Out:
# 497
# ['BM.GSR.TOTL.CD', 'BN.CAB.XOKA.CD', 'BX.GRT.EXTA.CD.DT', 'BX.GRT.TECH.CD.DT', 'BX.GSR.TOTL.CD']
# ['Imports of goods, services and primary income (BoP, current US$)', 'Current account balance (BoP, current US$)', 'Grants, excluding technical cooperation (current US$)', 'Technical cooperation grants (current US$)', 'Exports of goods, services and primary income (BoP, current US$)']

# %%
# Download CPIA (31)

cpia = wbdata.get_indicator(source=31, display = False)
#cpia

# %%
#Create list of International Debt Statistics IDs

cpia_ids = []
cpia_names = []

for num in range(0, len(cpia)):
    cpia_ids.append(cpia[num]["id"])
    cpia_names.append(cpia[num]["name"])
    
print(len(cpia_ids))
print(cpia_ids[0:5])
print(cpia_names[0:5])
# Out:
# 21
# ['IQ.CPA.BREG.XQ', 'IQ.CPA.DEBT.XQ', 'IQ.CPA.ECON.XQ', 'IQ.CPA.ENVR.XQ', 'IQ.CPA.FINQ.XQ']
# ['CPIA business regulatory environment rating (1=low to 6=high)', 'CPIA debt policy rating (1=low to 6=high)', 'CPIA economic management cluster average (1=low to 6=high)', 'CPIA policy and institutions for environmental sustainability rating (1=low to 6=high)', 'CPIA quality of budgetary and financial management rating (1=low to 6=high)']

# %%
# Download World Bureaucracy (64)

bureaucracy = wbdata.get_indicator(source=64, display = False)
#bureaucracy

# %%
#Create list of Bureaucracy IDs

bureaucracy_ids = []
bureaucracy_names = []

for num in range(0, len(bureaucracy)):
    bureaucracy_ids.append(bureaucracy[num]["id"])
    bureaucracy_names.append(bureaucracy[num]["name"])
    
print(len(bureaucracy_ids))
print(bureaucracy_ids[0:5])
print(bureaucracy_names[0:5])
# Out:
# 87
# ['BI.EMP.FRML.PB.ZS', 'BI.EMP.PWRK.PB.FE.ZS', 'BI.EMP.PWRK.PB.MA.ZS', 'BI.EMP.PWRK.PB.RU.ZS', 'BI.EMP.PWRK.PB.UR.ZS']
# ['Public sector employment as a share of formal employment', 'Public sector employment as a share of paid employment by gender (Female)', 'Public sector employment as a share of paid employment by gender (Male)', 'Public sector employment as a share of paid employment by location (Rural)', 'Public sector employment as a share of paid employment by location (Urban)']

# %%
# Download ESG (75)

esg = wbdata.get_indicator(source=64, display = False)
#esg

# %%
#Create list of ESG IDs

esg_ids = []
esg_names = []

for num in range(0, len(esg)):
    esg_ids.append(esg[num]["id"])
    esg_names.append(esg[num]["name"])
    
print(len(esg_ids))
print(esg_ids[0:5])
print(esg_names[0:5])
# Out:
# 87
# ['BI.EMP.FRML.PB.ZS', 'BI.EMP.PWRK.PB.FE.ZS', 'BI.EMP.PWRK.PB.MA.ZS', 'BI.EMP.PWRK.PB.RU.ZS', 'BI.EMP.PWRK.PB.UR.ZS']
# ['Public sector employment as a share of formal employment', 'Public sector employment as a share of paid employment by gender (Female)', 'Public sector employment as a share of paid employment by gender (Male)', 'Public sector employment as a share of paid employment by location (Rural)', 'Public sector employment as a share of paid employment by location (Urban)']

# %% [markdown]
# *Create Country Lists*

# %%
# Download Countries

countries = wbdata.get_country(display = False)
countries[0:5]
# Out:
# [{'id': 'ABW',
#   'iso2Code': 'AW',
#   'name': 'Aruba',
#   'region': {'id': 'LCN', 'value': 'Latin America & Caribbean '},
#   'adminregion': {'id': '', 'value': ''},
#   'incomeLevel': {'id': 'HIC', 'value': 'High income'},
#   'lendingType': {'id': 'LNX', 'value': 'Not classified'},
#   'capitalCity': 'Oranjestad',
#   'longitude': '-70.0167',
#   'latitude': '12.5167'},
#  {'id': 'AFG',
#   'iso2Code': 'AF',
#   'name': 'Afghanistan',
#   'region': {'id': 'SAS', 'value': 'South Asia'},
#   'adminregion': {'id': 'SAS', 'value': 'South Asia'},
#   'incomeLevel': {'id': 'LIC', 'value': 'Low income'},
#   'lendingType': {'id': 'IDX', 'value': 'IDA'},
#   'capitalCity': 'Kabul',
#   'longitude': '69.1761',
#   'latitude': '34.5228'},
#  {'id': 'AFR',
#   'iso2Code': 'A9',
#   'name': 'Africa',
#   'region': {'id': 'NA', 'value': 'Aggregates'},
#   'adminregion': {'id': '', 'value': ''},
#   'incomeLevel': {'id': 'NA', 'value': 'Aggregates'},
#   'lendingType': {'id': '', 'value': 'Aggregates'},
#   'capitalCity': '',
#   'longitude': '',
#   'latitude': ''},
#  {'id': 'AGO',
#   'iso2Code': 'AO',
#   'name': 'Angola',
#   'region': {'id': 'SSF', 'value': 'Sub-Saharan Africa '},
#   'adminregion': {'id': 'SSA',
#    'value': 'Sub-Saharan Africa (excluding high income)'},
#   'incomeLevel': {'id': 'LMC', 'value': 'Lower middle income'},
#   'lendingType': {'id': 'IBD', 'value': 'IBRD'},
#   'capitalCity': 'Luanda',
#   'longitude': '13.242',
#   'latitude': '-8.81155'},
#  {'id': 'ALB',
#   'iso2Code': 'AL',
#   'name': 'Albania',
#   'region': {'id': 'ECS', 'value': 'Europe & Central Asia'},
#   'adminregion': {'id': 'ECA',
#    'value': 'Europe & Central Asia (excluding high income)'},
#   'incomeLevel': {'id': 'UMC', 'value': 'Upper middle income'},
#   'lendingType': {'id': 'IBD', 'value': 'IBRD'},
#   'capitalCity': 'Tirane',
#   'longitude': '19.8172',
#   'latitude': '41.3317'}]

# %%
#Create list of Individual and Aggregate Countries with IDs

countries_individual = []
countries_aggregates = []

countries_individual_ids = []
countries_aggregates_ids = []

for num in range(0, len(countries)):
    if countries[num]['region']['value'] != 'Aggregates':
        countries_individual.append(countries[num])
        countries_individual_ids.append(countries[num]["id"])
    else:
        countries_aggregates.append(countries[num])
        countries_aggregates_ids.append(countries[num]["id"])

# %%
# View Number of Countries Individual and Aggregates

print("Countries Individual: ", len(countries_individual))
print("Countries Individual IDs: ", len(countries_individual_ids))

print("Country Aggregates: ", len(countries_aggregates))
print("Country Aggregate IDs: ", len(countries_aggregates_ids))

print("Total Countries: ", len(countries))
# Out:
# Countries Individual:  218
# Countries Individual IDs:  218
# Country Aggregates:  86
# Country Aggregate IDs:  86
# Total Countries:  304

# %%
# View Countries and Country IDs

print(countries_individual_ids[0:5])
countries_individual[0:5]
# Out:
# ['ABW', 'AFG', 'AGO', 'ALB', 'AND']
# [{'id': 'ABW',
#   'iso2Code': 'AW',
#   'name': 'Aruba',
#   'region': {'id': 'LCN', 'value': 'Latin America & Caribbean '},
#   'adminregion': {'id': '', 'value': ''},
#   'incomeLevel': {'id': 'HIC', 'value': 'High income'},
#   'lendingType': {'id': 'LNX', 'value': 'Not classified'},
#   'capitalCity': 'Oranjestad',
#   'longitude': '-70.0167',
#   'latitude': '12.5167'},
#  {'id': 'AFG',
#   'iso2Code': 'AF',
#   'name': 'Afghanistan',
#   'region': {'id': 'SAS', 'value': 'South Asia'},
#   'adminregion': {'id': 'SAS', 'value': 'South Asia'},
#   'incomeLevel': {'id': 'LIC', 'value': 'Low income'},
#   'lendingType': {'id': 'IDX', 'value': 'IDA'},
#   'capitalCity': 'Kabul',
#   'longitude': '69.1761',
#   'latitude': '34.5228'},
#  {'id': 'AGO',
#   'iso2Code': 'AO',
#   'name': 'Angola',
#   'region': {'id': 'SSF', 'value': 'Sub-Saharan Africa '},
#   'adminregion': {'id': 'SSA',
#    'value': 'Sub-Saharan Africa (excluding high income)'},
#   'incomeLevel': {'id': 'LMC', 'value': 'Lower middle income'},
#   'lendingType': {'id': 'IBD', 'value': 'IBRD'},
#   'capitalCity': 'Luanda',
#   'longitude': '13.242',
#   'latitude': '-8.81155'},
#  {'id': 'ALB',
#   'iso2Code': 'AL',
#   'name': 'Albania',
#   'region': {'id': 'ECS', 'value': 'Europe & Central Asia'},
#   'adminregion': {'id': 'ECA',
#    'value': 'Europe & Central Asia (excluding high income)'},
#   'incomeLevel': {'id': 'UMC', 'value': 'Upper middle income'},
#   'lendingType': {'id': 'IBD', 'value': 'IBRD'},
#   'capitalCity': 'Tirane',
#   'longitude': '19.8172',
#   'latitude': '41.3317'},
#  {'id': 'AND',
#   'iso2Code': 'AD',
#   'name': 'Andorra',
#   'region': {'id': 'ECS', 'value': 'Europe & Central Asia'},
#   'adminregion': {'id': '', 'value': ''},
#   'incomeLevel': {'id': 'HIC', 'value': 'High income'},
#   'lendingType': {'id': 'LNX', 'value': 'Not classified'},
#   'capitalCity': 'Andorra la Vella',
#   'longitude': '1.5218',
#   'latitude': '42.5075'}]

# %%
# Create Countries Individual DF

country_df = pd.DataFrame.from_dict(countries_individual)
country_df.head()
# Out:
#     id iso2Code         name  \
# 0  ABW       AW        Aruba
# 1  AFG       AF  Afghanistan
# 2  AGO       AO       Angola
# 3  ALB       AL      Albania
# 4  AND       AD      Andorra
#
#                                               region  \
# 0  {'id': 'LCN', 'value': 'Latin America & Caribb...
# 1               {'id': 'SAS', 'value': 'South Asia'}
# 2      {'id': 'SSF', 'value': 'Sub-Saharan Africa '}
# 3    {'id': 'ECS', 'value': 'Europe & Central Asia'}
# 4    {'id': 'ECS', 'value': 'Europe & Central Asia'}
#
#                                          adminregion  \
# 0                            {'id': '', 'value': ''}
# 1               {'id': 'SAS', 'value': 'South Asia'}
# 2  {'id': 'SSA', 'value': 'Sub-Saharan Africa (ex...
# 3  {'id': 'ECA', 'value': 'Europe & Central Asia ...
# 4                            {'id': '', 'value': ''}
#
#                                      incomeLevel  \
# 0          {'id': 'HIC', 'value': 'High income'}
# 1           {'id': 'LIC', 'value': 'Low income'}
# 2  {'id': 'LMC', 'value': 'Lower middle income'}
# 3  {'id': 'UMC', 'value': 'Upper middle income'}
# 4          {'id': 'HIC', 'value': 'High income'}
#
#                                 lendingType       capitalCity longitude  \
# 0  {'id': 'LNX', 'value': 'Not classified'}        Oranjestad  -70.0167
# 1             {'id': 'IDX', 'value': 'IDA'}             Kabul   69.1761
# 2            {'id': 'IBD', 'value': 'IBRD'}            Luanda    13.242
# 3            {'id': 'IBD', 'value': 'IBRD'}            Tirane   19.8172
# 4  {'id': 'LNX', 'value': 'Not classified'}  Andorra la Vella    1.5218
#
#    latitude
# 0   12.5167
# 1   34.5228
# 2  -8.81155
# 3   41.3317
# 4   42.5075

# %%
#TEST

country_df["region"][0].get("value")
# Out:
# 'Latin America & Caribbean '

# %%
# Reset Internal Dictionaries

for num in country_df.index:
    
    #Get the values for the dictionary columns
    region = country_df["region"][num].get("value")
    adminregion = country_df["adminregion"][num].get("value")
    incomeLevel = country_df["incomeLevel"][num].get("value")
    lendingType = country_df["lendingType"][num].get("value")
    
    #Input the new values
    country_df["region"][num] = region
    country_df["adminregion"][num] = adminregion
    country_df["incomeLevel"][num] = incomeLevel
    country_df["lendingType"][num] = lendingType
    
    #Print (if necessary)
    #print(region)

# %%
# View Country DF

country_df.head()
# Out:
#     id iso2Code         name                      region  \
# 0  ABW       AW        Aruba  Latin America & Caribbean
# 1  AFG       AF  Afghanistan                  South Asia
# 2  AGO       AO       Angola         Sub-Saharan Africa
# 3  ALB       AL      Albania       Europe & Central Asia
# 4  AND       AD      Andorra       Europe & Central Asia
#
#                                      adminregion          incomeLevel  \
# 0                                                         High income
# 1                                     South Asia           Low income
# 2     Sub-Saharan Africa (excluding high income)  Lower middle income
# 3  Europe & Central Asia (excluding high income)  Upper middle income
# 4                                                         High income
#
#       lendingType       capitalCity longitude  latitude
# 0  Not classified        Oranjestad  -70.0167   12.5167
# 1             IDA             Kabul   69.1761   34.5228
# 2            IBRD            Luanda    13.242  -8.81155
# 3            IBRD            Tirane   19.8172   41.3317
# 4  Not classified  Andorra la Vella    1.5218   42.5075

# %%
# Rename name to country

country_df = country_df.rename(columns={"name": "country"})
country_df.head()
# Out:
#     id iso2Code      country                      region  \
# 0  ABW       AW        Aruba  Latin America & Caribbean
# 1  AFG       AF  Afghanistan                  South Asia
# 2  AGO       AO       Angola         Sub-Saharan Africa
# 3  ALB       AL      Albania       Europe & Central Asia
# 4  AND       AD      Andorra       Europe & Central Asia
#
#                                      adminregion          incomeLevel  \
# 0                                                         High income
# 1                                     South Asia           Low income
# 2     Sub-Saharan Africa (excluding high income)  Lower middle income
# 3  Europe & Central Asia (excluding high income)  Upper middle income
# 4                                                         High income
#
#       lendingType       capitalCity longitude  latitude
# 0  Not classified        Oranjestad  -70.0167   12.5167
# 1             IDA             Kabul   69.1761   34.5228
# 2            IBRD            Luanda    13.242  -8.81155
# 3            IBRD            Tirane   19.8172   41.3317
# 4  Not classified  Andorra la Vella    1.5218   42.5075

# %%
# Sort by country

country_df = country_df.sort_values(by='country')
country_df.head()
# Out:
#      id iso2Code         country                      region  \
# 1   AFG       AF     Afghanistan                  South Asia
# 3   ALB       AL         Albania       Europe & Central Asia
# 55  DZA       DZ         Algeria  Middle East & North Africa
# 8   ASM       AS  American Samoa         East Asia & Pacific
# 4   AND       AD         Andorra       Europe & Central Asia
#
#                                           adminregion          incomeLevel  \
# 1                                          South Asia           Low income
# 3       Europe & Central Asia (excluding high income)  Upper middle income
# 55  Middle East & North Africa (excluding high inc...  Upper middle income
# 8         East Asia & Pacific (excluding high income)  Upper middle income
# 4                                                              High income
#
#        lendingType       capitalCity longitude  latitude
# 1              IDA             Kabul   69.1761   34.5228
# 3             IBRD            Tirane   19.8172   41.3317
# 55            IBRD           Algiers   3.05097   36.7397
# 8   Not classified         Pago Pago  -170.691  -14.2846
# 4   Not classified  Andorra la Vella    1.5218   42.5075

# %%
# Save Data

country_df.to_csv('../../2_Inputs/Culled/country_df.csv')

# %% [markdown]
# *Cull Data Using Indicators and Countries List*

# %%
# TEST Culling Data

test_df = wbdata.get_dataframe({'FP.CPI.TOTL.ZG': 'value'}, country=countries_individual_ids)
test_df
# Out:
#                   value
# country  date
# Aruba    2019       NaN
#          2018  3.580394
#          2017 -0.481315
#          2016 -0.886758
#          2015  0.475067
# ...                 ...
# Zimbabwe 2004       NaN
#          2003       NaN
#          2002       NaN
#          2001       NaN
#          2000       NaN
#
# [13020 rows x 1 columns]

# %%
# TEST 2: WB Data

test_df2 = wbdata.get_dataframe({wdi_ids[100]: wdi_names[100]}, country=countries_individual_ids)
test_df2
# Out:
#                Net bilateral aid flows from DAC donors, Italy (current US$)
# country  date
# Aruba    2019                                                NaN
#          2018                                                NaN
#          2017                                                NaN
#          2016                                                NaN
#          2015                                                NaN
# ...                                                          ...
# Zimbabwe 2004                                          1440000.0
#          2003                                          1120000.0
#          2002                                          2090000.0
#          2001                                          1740000.0
#          2000                                           710000.0
#
# [13020 rows x 1 columns]

# %%
## Pull WDI Data
#
#wdi_df = pd.DataFrame()
#
#for num, indicator, name in zip(range(1, len(wdi) + 1), wdi_ids, wdi_names):
#    if num % 10 == 0:
#        print(num, " / ", len(wdi), " : ", name)
#    df = wbdata.get_dataframe({indicator: name}, country=countries_individual_ids)
#    wdi_df = pd.concat([wdi_df, df], axis = 1)

# %%
## View WDI Data
#
#wdi_df

# %%
# Pull Doing Business Data

doing_business_df = pd.DataFrame()

for num, indicator, name in zip(range(1, len(doing_business) + 1), doing_business_ids, doing_business_names):
    if num % 10 == 0:
        print(num, " / ", len(doing_business), " : ", name)
    try:
        df = wbdata.get_dataframe({indicator: name}, country=countries_individual_ids)
    except:
        print(indicator, "failed")
        pass
    doing_business_df = pd.concat([doing_business_df, df], axis = 1)
# Out:
# 10  /  205  :  Enforcing contracts (DB04-15 methodology) - Score
# 20  /  205  :  Enforcing contracts: Quality of the judicial processes index (0-18) (DB17-20 methodology)
# 30  /  205  :  Ease of doing business index (1=most business-friendly regulations)
# 40  /  205  :  Dealing with construction permits: Quality of building regulations index (0-2) (DB16-20 methodology)
# 50  /  205  :  Getting credit (DB15-20 methodology) - Score
# 60  /  205  :  Getting credit: Credit bureau coverage (% of adults)
# IC.ELC.ACES.RK DB19 failed
# 70  /  205  :  Getting electricity: Mechanisms for monitoring outages (0-1) (DB16-20 methodology)
# 80  /  205  :  Getting electricity: System average interruption duration index (SAIDI) (DB16-20 methodology)
# 90  /  205  :  Starting a business: Time - Women (days)- Score
# 100  /  205  :  Registering property (DB05-15 methodology) - Score
# 110  /  205  :  Registering property: Procedures (number) - Score
# 120  /  205  :  Paying taxes: Time to comply with corporate income tax correction (hours) (DB17-20 methodology)
# 130  /  205  :  Paying taxes: Payments per year (number per year) - Score
# 140  /  205  :  Protecting minority investors (DB06-14 methodology) - Score
# 150  /  205  :  Protecting minority investors: Extent of director liability index (0-10) - Score
# 160  /  205  :  Protecting minority investors: Strength of minority investor protection index (0-50) (DB15-20 methodology)
# 170  /  205  :  Resolving insolvency: Recovery rate (cents on the dollar)
# 180  /  205  :  Trading across borders: Documents to import (number) (DB06-15 methodology)
# 190  /  205  :  Trading across borders: Time to export: Border compliance (hours) (DB16-20 methodology) - Score
# 200  /  205  :  Time to import: Documentary compliance (hours) (DB16-20 methodology)

# %%
# View Doing Business Data

doing_business_df.head()
# Out:
#                   Enforcing contracts: Alternative dispute resolution (0-3) (DB16-20 methodology)  \
# country     date
# Afghanistan 1960                                                NaN
#             1961                                                NaN
#             1962                                                NaN
#             1963                                                NaN
#             1964                                                NaN
#
#                   Enforcing contracts: Attorney fees (% of claim)  \
# country     date
# Afghanistan 1960                                              NaN
#             1961                                              NaN
#             1962                                              NaN
#             1963                                              NaN
#             1964                                              NaN
#
#                   Enforcing contracts: Cost (% of claim)  \
# country     date
# Afghanistan 1960                                     NaN
#             1961                                     NaN
#             1962                                     NaN
#             1963                                     NaN
#             1964                                     NaN
#
#                   Enforcing contracts: Cost (% of claim) - Score  \
# country     date
# Afghanistan 1960                                             NaN
#             1961                                             NaN
#             1962                                             NaN
#             1963                                             NaN
#             1964                                             NaN
#
#                   Enforcing contracts: Case management (0-6) (DB16-20 methodology)  \
# country     date
# Afghanistan 1960                                                NaN
#             1961                                                NaN
#             1962                                                NaN
#             1963                                                NaN
#             1964                                                NaN
#
#                   Enforcing contracts: Court automation (0-4) (DB17-20 methodology)  \
# country     date
# Afghanistan 1960                                                NaN
#             1961                                                NaN
#             1962                                                NaN
#             1963                                                NaN
#             1964                                                NaN
#
#                   Enforcing contracts: Court fees (% of claim)  \
# country     date
# Afghanistan 1960                                           NaN
#             1961                                           NaN
#             1962                                           NaN
#             1963                                           NaN
#             1964                                           NaN
#
#                  Enforcing contracts: Court structure and proceedings (0-5) (DB16 methodology)  \
# country     date
# Afghanistan 1960                                               None
#             1961                                               None
#             1962                                               None
#             1963                                               None
#             1964                                               None
#
#                   Enforcing contracts: Court structure and proceedings (0-5) (DB17-20 methodology)  \
# country     date
# Afghanistan 1960                                                NaN
#             1961                                                NaN
#             1962                                                NaN
#             1963                                                NaN
#             1964                                                NaN
#
#                   Enforcing contracts (DB04-15 methodology) - Score  ...  \
# country     date                                                     ...
# Afghanistan 1960                                                NaN  ...
#             1961                                                NaN  ...
#             1962                                                NaN  ...
#             1963                                                NaN  ...
#             1964                                                NaN  ...
#
#                  Trading across borders: Cost to import (US$ per container deflated)(DB06-15 methodology)  \
# country     date
# Afghanistan 1960                                                NaN
#             1961                                                NaN
#             1962                                                NaN
#             1963                                                NaN
#             1964                                                NaN
#
#                   Trading across borders: Cost to import (US$ per container)(DB06-15 methodology) - Score  \
# country     date
# Afghanistan 1960                                                NaN
#             1961                                                NaN
#             1962                                                NaN
#             1963                                                NaN
#             1964                                                NaN
#
#                   Trading across borders: Cost to import: Documentary compliance (USD) (DB16-20 methodology)  \
# country     date
# Afghanistan 1960                                                NaN
#             1961                                                NaN
#             1962                                                NaN
#             1963                                                NaN
#             1964                                                NaN
#
#                   Trading across borders: Cost to import: Documentary compliance (USD) (DB16-20 methodology) - Score  \
# country     date
# Afghanistan 1960                                                NaN
#             1961                                                NaN
#             1962                                                NaN
#             1963                                                NaN
#             1964                                                NaN
#
#                   Time to import: Documentary compliance (hours) (DB16-20 methodology)  \
# country     date
# Afghanistan 1960                                                NaN
#             1961                                                NaN
#             1962                                                NaN
#             1963                                                NaN
#             1964                                                NaN
#
#                   Time to import (days) (DB06-15 methodology)  \
# country     date
# Afghanistan 1960                                          NaN
#             1961                                          NaN
#             1962                                          NaN
#             1963                                          NaN
#             1964                                          NaN
#
#                   Trading across borders: Time to import: Border compliance (hours) (DB16-20 methodology) - Score  \
# country     date
# Afghanistan 1960                                                NaN
#             1961                                                NaN
#             1962                                                NaN
#             1963                                                NaN
#             1964                                                NaN
#
#                   Trading across borders: Time to import: Documentary compliance (hours) (DB16-20 methodology) - Score  \
# country     date
# Afghanistan 1960                                                NaN
#             1961                                                NaN
#             1962                                                NaN
#             1963                                                NaN
#             1964                                                NaN
#
#                  Trading across borders: Time to import (days) (DB06-15 methodology) - Score  \
# country     date
# Afghanistan 1960                                                NaN
#             1961                                                NaN
#             1962                                                NaN
#             1963                                                NaN
#             1964                                                NaN
#
#                   Rank: Trading across borders (1=most business-friendly regulations)
# country     date
# Afghanistan 1960                                                NaN
#             1961                                                NaN
#             1962                                                NaN
#             1963                                                NaN
#             1964                                                NaN
#
# [5 rows x 205 columns]

# %%
# Save Doing Business Data

doing_business_df.to_csv('../../2_Inputs/Culled/doing_business_df.csv')

# %%
# Pull, Print and Save WGI Data

wgi_df = pd.DataFrame()

for num, indicator, name in zip(range(1, len(wgi) + 1), wgi_ids, wgi_names):
    if num % 10 == 0:
        print(num, " / ", len(wgi), " : ", name)
    try:
        df = wbdata.get_dataframe({indicator: name}, country=countries_individual_ids)
    except:
        print(indicator, "failed")
        pass
    wgi_df = pd.concat([wgi_df, df], axis = 1)
    
print(wgi_df.head())

wgi_df.to_csv('../../2_Inputs/Culled/wgi_df.csv')
# Out:
# 10  /  36  :  Government Effectiveness: Percentile Rank, Lower Bound of 90% Confidence Interval
# 20  /  36  :  Rule of Law: Number of Sources
# 30  /  36  :  Regulatory Quality: Standard Error
#               Control of Corruption: Estimate  \
# country date
# Aruba   2018                         1.252027
#         2017                         1.291643
#         2016                         1.285848
#         2015                         1.297111
#         2014                         1.018918
#
#               Control of Corruption: Number of Sources  \
# country date
# Aruba   2018                                       2.0
#         2017                                       2.0
#         2016                                       2.0
#         2015                                       2.0
#         2014                                       2.0
#
#               Control of Corruption: Percentile Rank  \
# country date
# Aruba   2018                                87.01923
#         2017                                87.98077
#         2016                                89.42308
#         2015                                88.46154
#         2014                                81.73077
#
#               Control of Corruption: Percentile Rank, Lower Bound of 90% Confidence Interval  \
# country date
# Aruba   2018                                           79.32692
#         2017                                           79.80769
#         2016                                           76.92308
#         2015                                           76.92308
#         2014                                           69.23077
#
#               Control of Corruption: Percentile Rank, Upper Bound of 90% Confidence Interval  \
# country date
# Aruba   2018                                           92.30769
#         2017                                           92.30769
#         2016                                           92.78846
#         2015                                           92.78846
#         2014                                           90.86539
#
#               Control of Corruption: Standard Error  \
# country date
# Aruba   2018                               0.282670
#         2017                               0.282382
#         2016                               0.307186
#         2015                               0.290557
#         2014                               0.304744
#
#               Government Effectiveness: Estimate  \
# country date
# Aruba   2018                            1.058392
#         2017                            0.917742
#         2016                            0.893229
#         2015                            0.883569
#         2014                            0.891651
#
#               Government Effectiveness: Number of Sources  \
# country date
# Aruba   2018                                          2.0
#         2017                                          2.0
#         2016                                          2.0
#         2015                                          2.0
#         2014                                          2.0
#
#               Government Effectiveness: Percentile Rank  \
# country date
# Aruba   2018                                   80.28846
#         2017                                   79.32692
#         2016                                   76.44231
#         2015                                   76.44231
#         2014                                   75.48077
#
#               Government Effectiveness: Percentile Rank, Lower Bound of 90% Confidence Interval  \
# country date
# Aruba   2018                                           71.15385
#         2017                                           66.34615
#         2016                                           67.30769
#         2015                                           65.38461
#         2014                                           64.42308
#
#               ...  Regulatory Quality: Percentile Rank  \
# country date  ...
# Aruba   2018  ...                             77.88461
#         2017  ...                             84.13461
#         2016  ...                             88.94231
#         2015  ...                             90.38461
#         2014  ...                             88.46154
#
#               Regulatory Quality: Percentile Rank, Lower Bound of 90% Confidence Interval  \
# country date
# Aruba   2018                                           62.01923
#         2017                                           72.11539
#         2016                                           75.48077
#         2015                                           76.44231
#         2014                                           73.07692
#
#               Regulatory Quality: Percentile Rank, Upper Bound of 90% Confidence Interval  \
# country date
# Aruba   2018                                           90.38461
#         2017                                           94.71154
#         2016                                           98.07692
#         2015                                           99.03846
#         2014                                           97.11539
#
#               Regulatory Quality: Standard Error  \
# country date
# Aruba   2018                            0.364137
#         2017                            0.350700
#         2016                            0.359692
#         2015                            0.336364
#         2014                            0.353025
#
#               Voice and Accountability: Estimate  \
# country date
# Aruba   2018                            1.305925
#         2017                            1.294318
#         2016                            1.279304
#         2015                            1.273942
#         2014                            1.276822
#
#               Voice and Accountability: Number of Sources  \
# country date
# Aruba   2018                                          1.0
#         2017                                          1.0
#         2016                                          1.0
#         2015                                          1.0
#         2014                                          1.0
#
#               Voice and Accountability: Percentile Rank  \
# country date
# Aruba   2018                                   91.62562
#         2017                                   92.61084
#         2016                                   92.11823
#         2015                                   91.62562
#         2014                                   92.11823
#
#               Voice and Accountability: Percentile Rank, Lower Bound of 90% Confidence Interval  \
# country date
# Aruba   2018                                           77.33990
#         2017                                           73.89162
#         2016                                           71.92118
#         2015                                           72.41380
#         2014                                           71.92118
#
#               Voice and Accountability: Percentile Rank, Upper Bound of 90% Confidence Interval  \
# country date
# Aruba   2018                                           99.50739
#         2017                                          100.00000
#         2016                                          100.00000
#         2015                                          100.00000
#         2014                                          100.00000
#
#               Voice and Accountability: Standard Error
# country date
# Aruba   2018                                  0.249347
#         2017                                  0.282301
#         2016                                  0.291442
#         2015                                  0.276420
#         2014                                  0.267147
#
# [5 rows x 36 columns]

# %%
# Pull, Print and Save Debt Data

debt_df = pd.DataFrame()

for num, indicator, name in zip(range(1, len(debt) + 1), debt_ids, debt_names):
    if num % 10 == 0:
        print(num, " / ", len(debt), " : ", name)
    try:
        df = wbdata.get_dataframe({indicator: name}, country=countries_individual_ids)
    except:
        print(indicator, "failed")
        pass
    debt_df = pd.concat([debt_df, df], axis = 1)
    
print(debt_df.head())

debt_df.to_csv('../../2_Inputs/Culled/debt_df.csv')
# Out:
# 10  /  497  :  PPG, bilateral (AMT, current US$)
# 20  /  497  :  Principal repayments on external debt, general government sector (PPG) (AMT, current US$)
# 30  /  497  :  PPG, multilateral (AMT, current US$)
# 40  /  497  :  PPG, official creditors (AMT, current US$)
# 50  /  497  :  PPG, commercial banks (AMT, current US$)
# 60  /  497  :  PRVG, other private creditors (AMT, current US$)
# 70  /  497  :  Principal arrears, private creditors (current US$)
# 80  /  497  :  Commitments, official creditors (COM, current US$)
# 90  /  497  :  Currency composition of PPG debt, Pound sterling (%)
# 100  /  497  :  OPS, bilateral concessional (DIS, current US$)
# 110  /  497  :  Disbursements on external debt, public and publicly guaranteed (PPG) (DIS, current US$)
# 120  /  497  :  GG, multilateral concessional (DIS, current US$)
# 130  /  497  :  GG, bonds (DIS, current US$)
# 140  /  497  :  PNG, commercial banks and other creditors (DIS, current US$)
# 150  /  497  :  PRVG, private creditors (DIS, current US$)
# 160  /  497  :  GG, bilateral concessional (DOD, current US$)
# 170  /  497  :  Use of IMF credit (DOD, current US$)
# 180  /  497  :  PPG, IDA (DOD, current US$)
# 190  /  497  :  PRVG, multilateral concessional (DOD, current US$)
# 200  /  497  :  PRVG, bonds (DOD, current US$)
# 210  /  497  :  GG, other private creditors (DOD, current US$)
# 220  /  497  :  PS, private creditors (DOD, current US$)
# 230  /  497  :  Average grace period on new external debt commitments, private (years)
# 240  /  497  :  PRVG, bilateral (INT, current US$)
# 250  /  497  :  Interest payments on external debt, general government sector (PPG) (INT, current US$)
# 260  /  497  :  PPG, multilateral (INT, current US$)
# 270  /  497  :  PPG, official creditors (INT, current US$)
# 280  /  497  :  PPG, commercial banks (INT, current US$)
# 290  /  497  :  PRVG, other private creditors (INT, current US$)
# 300  /  497  :  Interest arrears, official creditors (current US$)
# 310  /  497  :  GG, bilateral (NFL, current US$)
# 320  /  497  :  Net flows on external debt, general government sector (PPG) (NFL, current US$)
# 330  /  497  :  Net financial flows, IDA (NFL, current US$)
# 340  /  497  :  PS, multilateral concessional (NFL, current US$)
# 350  /  497  :  GG, bonds (NFL, current US$)
# 360  /  497  :  PNG, commercial banks and other creditors (NFL, current US$)
# 370  /  497  :  PRVG, private creditors (NFL, current US$)
# 380  /  497  :  GG, bilateral concessional (NTR, current US$)
# 390  /  497  :  Net transfers on external debt, public and publicly guaranteed (PPG) (NTR, current US$)
# 400  /  497  :  OPS, multilateral concessional (NTR, current US$)
# 410  /  497  :  OPS, bonds (NTR, current US$)
# 420  /  497  :  PPG, other private creditors (NTR, current US$)
# 430  /  497  :  PS, private creditors (NTR, current US$)
# 440  /  497  :  PS, bilateral concessional (TDS, current US$)
# 450  /  497  :  PPG, IBRD (TDS, current US$)
# 460  /  497  :  PRVG, multilateral concessional (TDS, current US$)
# 470  /  497  :  PRVG, bonds (TDS, current US$)
# 480  /  497  :  GG, other private creditors (TDS, current US$)
# 490  /  497  :  Total amount of debt rescheduled (current US$)
#                   Imports of goods, services and primary income (BoP, current US$)  \
# country     date
# Afghanistan 1960                                                NaN
#             1961                                                NaN
#             1962                                                NaN
#             1963                                                NaN
#             1964                                                NaN
#
#                   Current account balance (BoP, current US$)  \
# country     date
# Afghanistan 1960                                         NaN
#             1961                                         NaN
#             1962                                         NaN
#             1963                                         NaN
#             1964                                         NaN
#
#                   Grants, excluding technical cooperation (current US$)  \
# country     date
# Afghanistan 1960                                                NaN
#             1961                                                NaN
#             1962                                                NaN
#             1963                                                NaN
#             1964                                                NaN
#
#                   Technical cooperation grants (current US$)  \
# country     date
# Afghanistan 1960                                         NaN
#             1961                                         NaN
#             1962                                         NaN
#             1963                                         NaN
#             1964                                         NaN
#
#                   Exports of goods, services and primary income (BoP, current US$)  \
# country     date
# Afghanistan 1960                                                NaN
#             1961                                                NaN
#             1962                                                NaN
#             1963                                                NaN
#             1964                                                NaN
#
#                   Foreign direct investment, net inflows in reporting economy (DRS, current US$)  \
# country     date
# Afghanistan 1960                                                NaN
#             1961                                                NaN
#             1962                                                NaN
#             1963                                                NaN
#             1964                                                NaN
#
#                   Primary income on FDI (current US$)  \
# country     date
# Afghanistan 1960                                  NaN
#             1961                                  NaN
#             1962                                  NaN
#             1963                                  NaN
#             1964                                  NaN
#
#                   Portfolio investment, equity (DRS, current US$)  \
# country     date
# Afghanistan 1960                                              NaN
#             1961                                              NaN
#             1962                                              NaN
#             1963                                              NaN
#             1964                                              NaN
#
#                   Personal remittances, received (current US$)  \
# country     date
# Afghanistan 1960                                           NaN
#             1961                                           NaN
#             1962                                           NaN
#             1963                                           NaN
#             1964                                           NaN
#
#                   PPG, bilateral (AMT, current US$)  ...  \
# country     date                                     ...
# Afghanistan 1960                                NaN  ...
#             1961                                NaN  ...
#             1962                                NaN  ...
#             1963                                NaN  ...
#             1964                                NaN  ...
#
#                   PRVG, private creditors (TDS, current US$)  \
# country     date
# Afghanistan 1960                                         NaN
#             1961                                         NaN
#             1962                                         NaN
#             1963                                         NaN
#             1964                                         NaN
#
#                   PS, private creditors (TDS, current US$)  \
# country     date
# Afghanistan 1960                                       NaN
#             1961                                       NaN
#             1962                                       NaN
#             1963                                       NaN
#             1964                                       NaN
#
#                   Total amount of debt rescheduled (current US$)  \
# country     date
# Afghanistan 1960                                             NaN
#             1961                                             NaN
#             1962                                             NaN
#             1963                                             NaN
#             1964                                             NaN
#
#                   Undisbursed external debt, total (UND, current US$)  \
# country     date
# Afghanistan 1960                                                NaN
#             1961                                                NaN
#             1962                                                NaN
#             1963                                                NaN
#             1964                                                NaN
#
#                   Undisbursed external debt, official creditors (UND, current US$)  \
# country     date
# Afghanistan 1960                                                NaN
#             1961                                                NaN
#             1962                                                NaN
#             1963                                                NaN
#             1964                                                NaN
#
#                   Undisbursed external debt, private creditors (UND, current US$)  \
# country     date
# Afghanistan 1960                                                NaN
#             1961                                                NaN
#             1962                                                NaN
#             1963                                                NaN
#             1964                                                NaN
#
#                   Total reserves (includes gold, current US$)  \
# country     date
# Afghanistan 1960                                          NaN
#             1961                                          NaN
#             1962                                          NaN
#             1963                                   45547800.0
#             1964                                   44619680.0
#
#                   Total reserves (% of total external debt)  \
# country     date
# Afghanistan 1960                                        NaN
#             1961                                        NaN
#             1962                                        NaN
#             1963                                        NaN
#             1964                                        NaN
#
#                   Total reserves in months of imports  GNI (current US$)
# country     date
# Afghanistan 1960                                  NaN       5.488888e+08
#             1961                                  NaN       5.600000e+08
#             1962                                  NaN       5.577778e+08
#             1963                                  NaN       7.666667e+08
#             1964                                  NaN       8.155556e+08
#
# [5 rows x 497 columns]

# %%
# Pull, Print and Save CPIA Data

cpia_df = pd.DataFrame()

for num, indicator, name in zip(range(1, len(cpia) + 1), cpia_ids, cpia_names):
    if num % 10 == 0:
        print(num, " / ", len(cpia), " : ", name)
    try:
        df = wbdata.get_dataframe({indicator: name}, country=countries_individual_ids)
    except:
        print(indicator, "failed")
        pass
    cpia_df = pd.concat([cpia_df, df], axis = 1)
    
print(cpia_df.head())

cpia_df.to_csv('../../2_Inputs/Culled/cpia_df.csv')
# Out:
# 10  /  21  :  IDA resource allocation index (1=low to 6=high)
# 20  /  21  :  CPIA trade rating (1=low to 6=high)
#               CPIA business regulatory environment rating (1=low to 6=high)  \
# country date
# Aruba   2019                                                NaN
#         2018                                                NaN
#         2017                                                NaN
#         2016                                                NaN
#         2015                                                NaN
#
#               CPIA debt policy rating (1=low to 6=high)  \
# country date
# Aruba   2019                                        NaN
#         2018                                        NaN
#         2017                                        NaN
#         2016                                        NaN
#         2015                                        NaN
#
#               CPIA economic management cluster average (1=low to 6=high)  \
# country date
# Aruba   2019                                                NaN
#         2018                                                NaN
#         2017                                                NaN
#         2016                                                NaN
#         2015                                                NaN
#
#               CPIA policy and institutions for environmental sustainability rating (1=low to 6=high)  \
# country date
# Aruba   2019                                                NaN
#         2018                                                NaN
#         2017                                                NaN
#         2016                                                NaN
#         2015                                                NaN
#
#               CPIA quality of budgetary and financial management rating (1=low to 6=high)  \
# country date
# Aruba   2019                                                NaN
#         2018                                                NaN
#         2017                                                NaN
#         2016                                                NaN
#         2015                                                NaN
#
#               CPIA financial sector rating (1=low to 6=high)  \
# country date
# Aruba   2019                                             NaN
#         2018                                             NaN
#         2017                                             NaN
#         2016                                             NaN
#         2015                                             NaN
#
#               CPIA fiscal policy rating (1=low to 6=high)  \
# country date
# Aruba   2019                                          NaN
#         2018                                          NaN
#         2017                                          NaN
#         2016                                          NaN
#         2015                                          NaN
#
#               CPIA gender equality rating (1=low to 6=high)  \
# country date
# Aruba   2019                                            NaN
#         2018                                            NaN
#         2017                                            NaN
#         2016                                            NaN
#         2015                                            NaN
#
#               CPIA building human resources rating (1=low to 6=high)  \
# country date
# Aruba   2019                                                NaN
#         2018                                                NaN
#         2017                                                NaN
#         2016                                                NaN
#         2015                                                NaN
#
#               IDA resource allocation index (1=low to 6=high)  ...  \
# country date                                                   ...
# Aruba   2019                                              NaN  ...
#         2018                                              NaN  ...
#         2017                                              NaN  ...
#         2016                                              NaN  ...
#         2015                                              NaN  ...
#
#               CPIA quality of public administration rating (1=low to 6=high)  \
# country date
# Aruba   2019                                                NaN
#         2018                                                NaN
#         2017                                                NaN
#         2016                                                NaN
#         2015                                                NaN
#
#               CPIA equity of public resource use rating (1=low to 6=high)  \
# country date
# Aruba   2019                                                NaN
#         2018                                                NaN
#         2017                                                NaN
#         2016                                                NaN
#         2015                                                NaN
#
#               CPIA property rights and rule-based governance rating (1=low to 6=high)  \
# country date
# Aruba   2019                                                NaN
#         2018                                                NaN
#         2017                                                NaN
#         2016                                                NaN
#         2015                                                NaN
#
#               CPIA social protection rating (1=low to 6=high)  \
# country date
# Aruba   2019                                              NaN
#         2018                                              NaN
#         2017                                              NaN
#         2016                                              NaN
#         2015                                              NaN
#
#               CPIA public sector management and institutions cluster average (1=low to 6=high)  \
# country date
# Aruba   2019                                                NaN
#         2018                                                NaN
#         2017                                                NaN
#         2016                                                NaN
#         2015                                                NaN
#
#               CPIA efficiency of revenue mobilization rating (1=low to 6=high)  \
# country date
# Aruba   2019                                                NaN
#         2018                                                NaN
#         2017                                                NaN
#         2016                                                NaN
#         2015                                                NaN
#
#               CPIA policies for social inclusion/equity cluster average (1=low to 6=high)  \
# country date
# Aruba   2019                                                NaN
#         2018                                                NaN
#         2017                                                NaN
#         2016                                                NaN
#         2015                                                NaN
#
#               CPIA structural policies cluster average (1=low to 6=high)  \
# country date
# Aruba   2019                                                NaN
#         2018                                                NaN
#         2017                                                NaN
#         2016                                                NaN
#         2015                                                NaN
#
#               CPIA trade rating (1=low to 6=high)  \
# country date
# Aruba   2019                                  NaN
#         2018                                  NaN
#         2017                                  NaN
#         2016                                  NaN
#         2015                                  NaN
#
#               CPIA transparency, accountability, and corruption in the public sector rating (1=low to 6=high)
# country date
# Aruba   2019                                                NaN
#         2018                                                NaN
#         2017                                                NaN
#         2016                                                NaN
#         2015                                                NaN
#
# [5 rows x 21 columns]

# %%
# Pull, Print and Save Bureacracy Data

bureaucracy_df = pd.DataFrame()

for num, indicator, name in zip(range(1, len(bureaucracy) + 1), bureaucracy_ids, bureaucracy_names):
    if num % 10 == 0:
        print(num, " / ", len(bureaucracy), " : ", name)
    try:
        df = wbdata.get_dataframe({indicator: name}, country=countries_individual_ids)
    except:
        print(indicator, "failed")
        pass
    bureaucracy_df = pd.concat([bureaucracy_df, df], axis = 1)
    
print(bureaucracy_df.head())

bureaucracy_df.to_csv('../../2_Inputs/Culled/bureaucracy_df.csv')
# Out:
# 10  /  87  :  Public sector employment as a share of total employment by location (Rural)
# 20  /  87  :  Share of private paid employees with a contract
# 30  /  87  :  Females as a share of private paid employees by occupation (Professionals)
# 40  /  87  :  Share of public paid employees with a contract
# 50  /  87  :  Number of public paid employees
# 60  /  87  :  Number of paid employees
# 70  /  87  :  Public sector wage premium by occupation (Professionals) (compared to formal wage employees)
# 80  /  87  :  Relative wage of Technicians in private sector  (using clerk as reference)
#                   Public sector employment as a share of formal employment  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Public sector employment as a share of paid employment by gender (Female)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Public sector employment as a share of paid employment by gender (Male)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Public sector employment as a share of paid employment by location (Rural)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Public sector employment as a share of paid employment by location (Urban)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Public sector employment as a share of paid employment  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Number of employed individuals  \
# country     date
# Afghanistan 2016                             NaN
#             2015                             NaN
#             2014                             NaN
#             2013                             NaN
#             2012                             NaN
#
#                   Public sector employment as a share of total employment by gender (Female)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Public sector employment as a share of total employment by gender (Male)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Public sector employment as a share of total employment by location (Rural)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   ...  \
# country     date  ...
# Afghanistan 2016  ...
#             2015  ...
#             2014  ...
#             2013  ...
#             2012  ...
#
#                   Relative wage of Professionals in private sector (using clerk as reference)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Relative wage of Senior officials in private sector (using clerk as reference)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Relative wage of Technicians in private sector  (using clerk as reference)   \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Female to male wage ratio in the public sector (using median)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Female to male wage ratio in the public sector (using mean)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Relative wage of Professionals in public sector (using clerk as reference)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Relative wage of Senior officials in public sector (using clerk as reference)   \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Relative wage of Technicians in public sector (using clerk as reference)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Wage bill as a percentage of GDP  \
# country     date
# Afghanistan 2016                               NaN
#             2015                               NaN
#             2014                               NaN
#             2013                               NaN
#             2012                               NaN
#
#                   Wage bill as a percentage of Public Expenditure
# country     date
# Afghanistan 2016                                              NaN
#             2015                                              NaN
#             2014                                              NaN
#             2013                                              NaN
#             2012                                              NaN
#
# [5 rows x 87 columns]

# %%
# Pull, Print and Save ESG Data

esg_df = pd.DataFrame()

for num, indicator, name in zip(range(1, len(esg) + 1), esg_ids, esg_names):
    if num % 10 == 0:
        print(num, " / ", len(esg), " : ", name)
    try:
        df = wbdata.get_dataframe({indicator: name}, country=countries_individual_ids)
    except:
        print(indicator, "failed")
        pass
    esg_df = pd.concat([esg_df, df], axis = 1)
    
print(esg_df.head())

esg_df.to_csv('../../2_Inputs/Culled/esg_df.csv')
# Out:
# 10  /  87  :  Public sector employment as a share of total employment by location (Rural)
# 20  /  87  :  Share of private paid employees with a contract
# 30  /  87  :  Females as a share of private paid employees by occupation (Professionals)
# 40  /  87  :  Share of public paid employees with a contract
# 50  /  87  :  Number of public paid employees
# 60  /  87  :  Number of paid employees
# 70  /  87  :  Public sector wage premium by occupation (Professionals) (compared to formal wage employees)
# 80  /  87  :  Relative wage of Technicians in private sector  (using clerk as reference)
#                   Public sector employment as a share of formal employment  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Public sector employment as a share of paid employment by gender (Female)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Public sector employment as a share of paid employment by gender (Male)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Public sector employment as a share of paid employment by location (Rural)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Public sector employment as a share of paid employment by location (Urban)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Public sector employment as a share of paid employment  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Number of employed individuals  \
# country     date
# Afghanistan 2016                             NaN
#             2015                             NaN
#             2014                             NaN
#             2013                             NaN
#             2012                             NaN
#
#                   Public sector employment as a share of total employment by gender (Female)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Public sector employment as a share of total employment by gender (Male)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Public sector employment as a share of total employment by location (Rural)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   ...  \
# country     date  ...
# Afghanistan 2016  ...
#             2015  ...
#             2014  ...
#             2013  ...
#             2012  ...
#
#                   Relative wage of Professionals in private sector (using clerk as reference)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Relative wage of Senior officials in private sector (using clerk as reference)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Relative wage of Technicians in private sector  (using clerk as reference)   \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Female to male wage ratio in the public sector (using median)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Female to male wage ratio in the public sector (using mean)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Relative wage of Professionals in public sector (using clerk as reference)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Relative wage of Senior officials in public sector (using clerk as reference)   \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Relative wage of Technicians in public sector (using clerk as reference)  \
# country     date
# Afghanistan 2016                                                NaN
#             2015                                                NaN
#             2014                                                NaN
#             2013                                                NaN
#             2012                                                NaN
#
#                   Wage bill as a percentage of GDP  \
# country     date
# Afghanistan 2016                               NaN
#             2015                               NaN
#             2014                               NaN
#             2013                               NaN
#             2012                               NaN
#
#                   Wage bill as a percentage of Public Expenditure
# country     date
# Afghanistan 2016                                              NaN
#             2015                                              NaN
#             2014                                              NaN
#             2013                                              NaN
#             2012                                              NaN
#
# [5 rows x 87 columns]
